# %%
import pandas as pd

# %%
matches_summary = pd.read_csv("all_season_summary.csv")

# %%
matches_summary.groupby(['season'])

# %%
winners = matches_summary['winner'].tolist()

# %%
from collections import Counter

winners_count = Counter(winners)
winners_count
# Out:
# Counter({'CSK': 107,
#          'DC': 86,
#          'RCB': 91,
#          'RR': 81,
#          'MI': 120,
#          'KXIP': 88,
#          'KKR': 99,
#          'SRH': 95,
#          'No Result': 11,
#          'RPS': 15,
#          'GL': 13,
#          'PWI': 12,
#          'Kochi': 6})

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wordcloud = WordCloud().generate_from_frequencies(winners_count)

plt.figure(figsize = (30, 20))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
